# %%
import numpy as np
import tensorflow as tf
import pandas as pd

# %%
x_data = np.linspace(0.0,10.0,1000)

# %%
noise = np.random.randn(len(x_data))

# %%
#y = mx + b, b = 5
y_true = (0.5 * x_data) + 5 + noise

# %%
x_df = pd.DataFrame(data = x_data, columns=['X_Data'])

y_df = pd.DataFrame(data = y_true, columns=['Y'])

# %%
x_df.head()
y_df.head()
# Out:
#           Y
# 0  5.026618
# 1  4.626571
# 2  5.456516
# 3  5.029340
# 4  4.898215

# %%
my_data = pd.concat([x_df,y_df],axis=1)

# %%
my_data.head()
# Out:
#     X_Data         Y
# 0  0.00000  5.026618
# 1  0.01001  4.626571
# 2  0.02002  5.456516
# 3  0.03003  5.029340
# 4  0.04004  4.898215

# %%
my_data.sample(n=250).plot(kind = 'scatter',x='X_Data', y = 'Y')

# %%
#Estimator API
feat_cols = [tf.feature_column.numeric_column('x',shape=[1])]

# %%
estimator = tf.estimator.LinearRegressor(feature_columns=feat_cols)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\INSAKU~1\AppData\Local\Temp\tmp5my2x4qu
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\INSAKU~1\\AppData\\Local\\Temp\\tmp5my2x4qu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %%
# Train Test split
from sklearn.model_selection import train_test_split

# %%
x_train, x_eval, y_train, y_eval = train_test_split(x_data, y_true, test_size=0.3, random_state=0)

# %%
input_func = tf.estimator.train(x_train,y_train,batch_size=4,num_epochs=None, shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-1e58c0576ff1> in <module>
# ----> 1 input_func = tf.estimator.train(x_train,y_train,batch_size=4,num_epochs=None, shuffle=True)
#
# AttributeError: module 'tensorflow_core.estimator' has no attribute 'train'

# %%
input_func = tf.estimator.input_func.
